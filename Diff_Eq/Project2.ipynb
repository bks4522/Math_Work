# %%
import sympy as smp
from sympy import *
import numpy as np
from numpy import *
import scipy as sp
from scipy.integrate import solve_ivp
from scipy.interpolate import interp1d
from scipy.integrate import odeint
from scipy.optimize import fsolve
import matplotlib.pyplot as plt
import scienceplots
plt.style.use(['science', 'notebook', 'grid'])

x, y, t, n, a, b, C, c, r, u, s = smp.symbols('x y t n a b C c r u s')
f, g, m, h = smp.symbols('f g m h', cls=smp.Function)

# %%
# Define the system of differential equations
def system(x, t):
    x1, x2 = x
    dx1dt = -3*x1 - 200*x2
    dx2dt = 200*x1 - 2*x2
    return [dx1dt, dx2dt]

# Define the time points
t = np.linspace(0, 1, 1000)

# Define the initial conditions
x0 = [2, -10]

# Solve the system of differential equations
x = odeint(system, x0, t)

# Plot the solutions
plt.figure()
plt.plot(t, x[:, 0], 'r', linewidth=2, label='x1(t)')
plt.plot(t, x[:, 1], 'b', linewidth=2, label='x2(t)')
plt.xlabel('Time (t)')
plt.ylabel('Solutions (x1(t), x2(t))')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Define the system of differential equations
def system(z, t):
    z1, z2, z3 = z
    dz1dt = z2
    dz2dt = z3
    dz3dt = -19/12*z3 - 19/24*z2 - 1/8*z1 + (1 if 1 <= t < 10 else 0)
    return [dz1dt, dz2dt, dz3dt]

# Define the time points
t = np.linspace(0, 35, 1000)

# Define the initial conditions
z0 = [0, 0, 0]

# Solve the system of differential equations
z = odeint(system, z0, t)

# Plot the solution
plt.figure()
plt.plot(t, z[:, 0], 'r', linewidth=2)
plt.xlabel('Time (t)')
plt.ylabel('Solution (y(t))')
plt.grid(True)
plt.show()

# %%
# Define the system of first-order differential equations
def system(t, yz):
    y, z = yz
    dydt = z
    dzdt = -6*z - 5*y + 3 if t == 4 else 0
    return [dydt, dzdt]

# Define the time points
t = np.linspace(0, 10, 1000)

# Define the initial conditions
yz0 = [5, 2]

# Solve the system of differential equations
sol = solve_ivp(system, [0, 10], yz0, t_eval=t)

# Plot the solution
plt.figure()
plt.plot(sol.t, sol.y[0], 'r', linewidth=2)
plt.xlabel('Time (t)')
plt.ylabel('Solution (y(t))')
plt.grid(True)
plt.show()
