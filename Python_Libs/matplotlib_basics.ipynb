# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use(['science', 'notebook', 'grid'])

# %% [markdown]
# Line Plots

# %%
x = np.linspace(0, 15, 30)
y = np.sin(x) + 0.1*np.random.randn(len(x))

plt.plot(x, y)

# %%
# -- = dashed line
# o = dot at each data point
# lw = line width
# ms = marker size
plt.plot(x, y, 'o--', color = 'purple', lw = .5, ms = 5)

# %%
plt.figure(figsize = (5, 2)) # Size of graph
plt.plot(x, y)

# %%
plt.figure(figsize = (8, 3))
plt.plot(x, y)
plt.xlabel('Time [s]', fontsize = 16)
plt.ylabel('Voltage [V]')
plt.title('Voltage in 3rd Electrode')
plt.show()

# %%
plt.figure(figsize = (8, 3))
plt.plot(x, y, label = 'Component 1')
plt.xlabel('Time [s]', fontsize = 16)
plt.ylabel('Voltage [V]')
plt.title('Voltage in 3rd Electrode')
plt.legend(loc = 'lower right', fontsize = 18)
plt.show()

# %%
x2 = np.linspace(0, 15, 100)
y2 = np.sin(x2)

plt.figure(figsize = (8, 3))
plt.plot(x, y, 'o--', label = 'Data', zorder = 100, color = 'red', lw = 1)
plt.plot(x2, y2, label = 'Theory', color = 'blue')
plt.xlabel('Time [s]', fontsize = 16)
plt.ylabel('Voltage [V]')
plt.title('Voltage in 3rd Electrode')
plt.legend(loc = 'lower right', fontsize = 12)
plt.show()

# %%
plt.figure(figsize = (8, 3))
plt.plot(x, y, 'o', label = 'Data', zorder = 100)
plt.plot(x2, y2, label = 'Theory')
plt.xlabel('Time [s]', fontsize = 16)
plt.ylabel('Voltage [V]')
plt.title('Voltage in 3rd Electrode')
plt.legend(loc = 'upper right', fontsize = 12, ncol = 2) # ncol = number of columns for legend
plt.ylim(top = 2) # Extends graph limit
plt.show()

# %% [markdown]
# Histograms

# %%
res = np.random.randn(1000)*0.2 + 0.4

# Quick Histogram
plt.figure(figsize = (8, 3))
plt.hist(res)
# Out:
# (array([ 18.,  47., 110., 167., 228., 182., 151.,  69.,  21.,   7.]),
#  array([-0.15027018, -0.03455741,  0.08115536,  0.19686814,  0.31258091,
#          0.42829368,  0.54400645,  0.65971923,  0.775432  ,  0.89114477,
#          1.00685755]),
#  <BarContainer object of 10 artists>)

# %%
# Change number of bins

plt.figure(figsize = (8, 3))
plt.hist(res, bins = 30)
plt.show()

# %%
# Convert to density plot

plt.figure(figsize = (8, 3))
plt.hist(res, bins = 30, density = True) # [density = True] = makes the area equal to 1
plt.show()

# %%
# Different style bins (plotting multiple histograms)

res2 = np.random.randn(1000)*0.2 + 0.4

plt.figure(figsize = (8, 3))
plt.hist(res, bins = 30, density = True, histtype = 'step')
plt.hist(res2, bins = 30, density = True, histtype = 'step')
plt.xlabel('$\hat{E} -E$', fontsize = 20)
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# More advanced APIs
#
# Plots such as:
#
# - Multiple subplots on one figure
#
# - Conveniently adding texts to plots
#
# - Creating animations

# %%
# Single Axes in one figure

fig, ax = plt.subplots(1, 1, figsize = (12, 4))
ax.plot(x, y, 'o--', color = 'red', lw = 0.4, ms = 3)
ax.text(0.1, 0.1, 'Informational Text', transform = ax.transAxes)
ax.set_xlabel('Time [s]')
ax.set_ylabel(r'$\frac{d}{dx} f(x)$', fontsize = 15)
plt.show()

# %%
# Multiple Axes in one figure

fig, axes = plt.subplots(3, 2, figsize = (8, 8))
ax = axes[0][0]
ax.plot(x, y, 'o--', color = 'red', lw = 0.4, ms = 3)
ax.text(0.1, 0.1, 'Informational Text', transform = ax.transAxes)
ax.set_title('Points Plotted')

ax = axes[0][1]
ax.hist(res, bins = 30, density = True, histtype = 'step', label = 'C1')
ax.hist(res2, bins = 30, density = True, histtype = 'step', label = 'C2')
ax.set_xlabel('$\hat{E}-E$')
ax.legend()
ax.set_title('Histogram')

fig.tight_layout()
fig.suptitle('Title of All Plots', y = 1.03, fontsize = 25)
plt.show()

# %%
# Adjusting x-ticks

fig, ax = plt.subplots(1, 1, figsize = (8,3))
ax.plot(x, y, 'o--', color = 'red', lw = 1, ms = 5)
ax.text(0.1, 0.1, 'Informational Text', transform = ax.transAxes)
ax.set_xlabel('Time [s]')
ax.set_ylabel(r'$\frac{d}{dx} f(x)$', fontsize = 15)
ax.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax.grid('minor')
plt.show()

# %% [markdown]
# Example

# %%
# Info

res_a1 = 0.2*np.random.randn(1000)+0.4
res_b1 = 0.25*np.random.randn(1000)+0.4
res_a2 = 0.21*np.random.randn(1000)+0.3
res_b2 = 0.22*np.random.randn(1000)+0.3

# %%
# Strings

textstr1 = '\n'.join((
    r'$\sigma_a=%.4f$' % (np.std(res_a1)),
    r'$\sigma_b=%.4f$' % (np.std(res_b1))))

textstr2 = '\n'.join((
    r'$\sigma_a=%.4f$' % (np.std(res_a2)),
    r'$\sigma_b=%.4f$' % (np.std(res_b2))))

# %%
# Plot # 1

plt.hist(res_a1, bins = 100, histtype = 'step')
plt.hist(res_b1, bins = 100, histtype = 'step')
plt.show()

# %%
# Plot # 2

fig, axes = plt.subplots(1, 2, figsize = (10,3.5))
ax = axes[0]
ax.hist(res_a1, bins = 30, density = True, histtype = 'step', label = 'Method A', color = 'blue')
ax.hist(res_b1, bins = 30, density = True, histtype = 'step', label = 'Method B', color = 'red')
ax.text(0.05, 0.81, textstr1, transform = ax.transAxes,
       bbox = dict(facecolor = 'white', edgecolor='black'), size = 12)
ax.legend(fontsize = 10, fancybox = False, edgecolor = 'black')
ax.set_ylabel('Frequency')
ax.set_title('Trial 1')


ax = axes[1]
ax.hist(res_a2, bins = 30, density = True, histtype = 'step', label = 'Method 1', color = 'blue')
ax.hist(res_b2, bins = 30, density = True, histtype = 'step', label = 'Method 2', color = 'red')
ax.text(0.05, 0.81, textstr2, transform = ax.transAxes,
       bbox = dict(facecolor = 'white', edgecolor = 'black'), size = 12)
ax.set_title('Trial 2')
fig.text(0.5, -0.04, '$\Delta E$ [Joules]', ha = 'center', size = 20)
plt.savefig('trial.png', dpi = 200)
#plt.savefig('ExamplePlot.png', dpi = 200) # Saves to computer
plt.show()

# %% [markdown]
# 2D Plots (2 independent variables)

# %%
plt.style.use(['default'])

_ = np.linspace(-1, 1, 100)
x, y = np.meshgrid(_,_)
z = x**2+x*y

# %%
# Filled-in Contour Plots

#plt.contourf(x, y, z)
#plt.contourf(x, y, z, levels = 30) # Adds more contours
#plt.contourf(x, y, z, levels = 30, vmin = 0.7) # Everything 0.7 or less = darkest color
#plt.contourf(x, y, z, levels = 30, vmax = 1.45) # Everything 1.45 or over = brightest color
plt.contourf(x, y, z, cmap = 'plasma') # Different colors! Check out Matplotlib for all color maps

plt.colorbar(label = 'Color Bar')
plt.xlabel('Horizontal Label')
plt.ylabel('Vartical label')
# Out:
# Text(0, 0.5, 'Vartical label')

# %% [markdown]
# Contour Plot

# %%
cs = plt.contour(x, y, z, levels = 20)
plt.clabel(cs, fontsize = 8)
# Out:
# <a list of 28 text.Text objects>

# %% [markdown]
# 3D Surface Plots

# %%
fig, ax = plt.subplots(subplot_kw = {"projection": "3d"})
ax.plot_surface(x, y, z, cmap = 'coolwarm', linewidth = 0, antialiased = False)
ax.view_init(elev = 10, azim = 50)

# %% [markdown]
# Stream Plots (Plotting Vector Fields)

# %%
w = 3
_ = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(_ , _)
U = -1 - X**2 + Y
V = 1 + X - Y**2
speed = np.sqrt(U**2 + V**2)

# %%
fig, axes = plt.subplots(2, 2, figsize = (7, 7))
ax = axes[0][0]
ax.streamplot(X, Y, U, V)

ax = axes[0][1]
ax.streamplot(X, Y, U, V, color = speed)

ax = axes[1][0]
lw = 5*speed / speed.max()
ax.streamplot(X, Y, U, V, linewidth = lw)

ax = axes[1][1]
seed_points = np.array([[0,1], [1,0]])
ax.streamplot(X, Y, U, V, color = U, linewidth = 2, cmap = 'autumn', start_points = seed_points)

ax.grid()

# %% [markdown]
# Image Reading

# %%
im = plt.imread(r"C:\Users\bense\Code1\VSCode\Jupyter_Notebooks\Maths\AgnusDei.jpg")
#im # Pixels arranged in a Numpy array
plt.imshow(im)

# %% [markdown]
# Animations

# %% [markdown]
# Animations require relating time of problem to the frame of animation, then specify frames/sec

# %%
# Sin wave moving at 3 m/s

def f(x,t):
    return np.sin(x - 3*t)

x = np.linspace(0, 10*np.pi, 1000)
t = np.arange(0, 24, 1/60)
X, T = np.meshgrid(x, t)
F = f(X, T)

plt.plot(x, F[1])

# %% [markdown]
# Creating Animation

# %%
from matplotlib import animation
from matplotlib.animation import PillowWriter

# %%
fig, ax = plt.subplots(1,1, figsize = (8,4))
ln1, = plt.plot([], [])
time_text = ax.text(0.65, 0.95, '', fontsize = 15, bbox = dict(facecolor = 'white', edgecolor = 'black'), transform = ax.transAxes)
ax.set_xlim(0,10*np.pi)
ax.set_ylim(-1.5, 1.5)

def animate(i):
    ln1.set_data(x, F[i])
    time_text.set_text('t = {:.2f}'.format(i/60))
    
ani = animation.FuncAnimation(fig, animate, frames = 240, interval = 50)
ani.save(r'C:\Users\bense\Code1\VSCode\Jupyter_Notebooks\Maths\ani.gif',writer = 'pillow',fps = 50,dpi = 100)

# %%
# 3D Rotating Gifs

_ = np.linspace(-1, 1, 100)
x, y = np.meshgrid(_, _)
z = x**2 + x*y

fig, ax = plt.subplots(subplot_kw = {"projection": "3d"})
ax.plot_surface(x, y, z, cmap = 'coolwarm', linewidth = 0, antialiased = False), ax.view_init(elev=10, azim=0)

def animate(i):
    ax.view_init(elev = 10, azim = 3*i)
    
ani = animation.FuncAnimation(fig, animate, frames = 120, interval = 50)
ani.save(r'C:\Users\bense\Code1\VSCode\Jupyter_Notebooks\Maths\3D_rotating.gif',writer='pillow',fps = 30,dpi = 100)
